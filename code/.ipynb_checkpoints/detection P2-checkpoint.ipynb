# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt
import PIL
import os
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
import cv2
import shutil
import visualkeras
# %matplotlib inline

# %%
# Label dictionary
# No tumor = 0
# Tumor = 1

# %%
t = cv2.imread('../dataset/yes/Y3.jpg')
t.shape
# Out:
# (519, 456, 3)

# %%
# Let's read the image by passing its path
# and resize it to be 128x128
def readImg(path):
    img = cv2.imread(path)
    img = cv2.resize(img, (128, 128))
    return img

# %%
# Grabbing all the datasets
noTumors = os.listdir(path='../dataset/no/')
yesTumors = os.listdir(path='../dataset/yes/')

# %%
# Let's create a single list containing all images (test and train)
yesImg = []
noImg = []

for i in noTumors:
    yesImg.append(readImg('../dataset/no/' + i))
for i in yesTumors:
    yesImg.append(readImg('../dataset/yes/' + i))

images = noImg + yesImg

# %%
# We're also creating a list with all labels according to 
# each image
noLabels = ['0'] * len(noTumors)
yesLabels = ['1'] * len(yesTumors)

labels = noLabels + yesLabels

# %%
# We can now separate the data into training and testing.
# test size will be of 15% and we'll shuffle the data.
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.15, shuffle=True)

# %%
print(y_train[5])
plt.imshow(X_train[5])
# Out:
# 1

# %%
# Let's show all the images and compare to the lables to make sure
# they're all consistent and true to feed to the NN
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    if y_train[i] == '0':
        plt.xlabel('No Tumor - 0', color='g')
    else:
        plt.xlabel('Tumor Found - 1', color='r')
    
plt.show()

# %%
# changing from list to numpy array, and changing the type of the 
# labels to be int
trainImages = np.asarray(X_train)
trainLabels = np.asarray(y_train).astype(np.int)
testImages = np.asarray(X_test)
testLabels = np.asarray(y_test).astype(np.int)

# %%
# The NN model :)
model = tf.keras.Sequential()

# First layer: 16 filters, kernel size of 3x3, Relu activation
# We'll apply max pooling and a dropout layer.
model.add(tf.keras.layers.Conv2D(filters=16,kernel_size=3, activation='relu', input_shape=(128, 128,3))) 
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(rate=0.45))

# Second layer: 36 filters, kernel size of 3x3, Relu activation
# Followed by a max pooling layer and a dropout layer
model.add(tf.keras.layers.Conv2D(filters=36,kernel_size=3, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(rate=0.25))

# Third layer: 56 filters, kernel size of 3x3 and Relu activation
# Max pooling and dropout layers after the third layer
model.add(tf.keras.layers.Conv2D(filters=56, kernel_size=3, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(rate=0.25))

# Flattening layer
model.add(tf.keras.layers.Flatten())


# Dense layer with 512 units, using Sigmoid as activation
# followed by drouput with rate of 0.15
model.add(tf.keras.layers.Dense(units=512, activation='sigmoid'))
model.add(tf.keras.layers.Dropout(rate=0.15))

# Last dense layer with 1 unit and Sigmoid as activation
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
# Compiling the model using cross entropy as loss function
# and SGD as optimizer
model.compile(loss='binary_crossentropy',
             optimizer=tf.keras.optimizers.SGD(),
             metrics=['acc'])

# %%
# Let's train the layers with batch size of 32 and 200 epochs
# should last about 2 - 3 minutes on CPU
history = model.fit(trainImages,
         trainLabels,
         batch_size=32,
         epochs=200,
         validation_data=(testImages, testLabels))
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 111ms/step - loss: 0.7343 - acc: 0.5535 - val_loss: 0.6487 - val_acc: 0.6053
# Epoch 2/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.6935 - acc: 0.6233 - val_loss: 0.5259 - val_acc: 0.8158
# Epoch 3/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.6287 - acc: 0.6512 - val_loss: 0.5137 - val_acc: 0.7895
# Epoch 4/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.6366 - acc: 0.6419 - val_loss: 0.5484 - val_acc: 0.8158
# Epoch 5/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.6314 - acc: 0.6651 - val_loss: 0.6154 - val_acc: 0.6842
# Epoch 6/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.6096 - acc: 0.6837 - val_loss: 0.5041 - val_acc: 0.8158
# Epoch 7/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.6072 - acc: 0.6326 - val_loss: 0.5281 - val_acc: 0.8421
# Epoch 8/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.5918 - acc: 0.6512 - val_loss: 0.5593 - val_acc: 0.8158
# Epoch 9/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.6048 - acc: 0.7116 - val_loss: 0.5368 - val_acc: 0.7895
# Epoch 10/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.6111 - acc: 0.6837 - val_loss: 0.5823 - val_acc: 0.6842
# Epoch 11/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.6338 - acc: 0.6605 - val_loss: 0.5192 - val_acc: 0.8158
# Epoch 12/200
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5811 - acc: 0.6744 - val_loss: 0.5006 - val_acc: 0.8158
# Epoch 13/200
# 7/7 [==============================] - 1s 113ms/step - loss: 0.6159 - acc: 0.6977 - val_loss: 0.4787 - val_acc: 0.7632
# Epoch 14/200
# 7/7 [==============================] - 1s 118ms/step - loss: 0.5737 - acc: 0.6837 - val_loss: 0.4504 - val_acc: 0.7632
# Epoch 15/200
# 7/7 [==============================] - 1s 111ms/step - loss: 0.5839 - acc: 0.6930 - val_loss: 0.5572 - val_acc: 0.7632
# Epoch 16/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5659 - acc: 0.7395 - val_loss: 0.4608 - val_acc: 0.7895
# Epoch 17/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.5742 - acc: 0.7302 - val_loss: 0.5153 - val_acc: 0.8158
# Epoch 18/200
# 7/7 [==============================] - 1s 122ms/step - loss: 0.5731 - acc: 0.7302 - val_loss: 0.4893 - val_acc: 0.8158
# Epoch 19/200
# 7/7 [==============================] - 1s 116ms/step - loss: 0.5720 - acc: 0.7256 - val_loss: 0.5527 - val_acc: 0.7895
# Epoch 20/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5767 - acc: 0.7023 - val_loss: 0.4924 - val_acc: 0.8158
# Epoch 21/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.5779 - acc: 0.7209 - val_loss: 0.4447 - val_acc: 0.8158
# Epoch 22/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5649 - acc: 0.7163 - val_loss: 0.4662 - val_acc: 0.8158
# Epoch 23/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5508 - acc: 0.7349 - val_loss: 0.4926 - val_acc: 0.7895
# Epoch 24/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5759 - acc: 0.7256 - val_loss: 0.4725 - val_acc: 0.8158
# Epoch 25/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.5595 - acc: 0.7395 - val_loss: 0.4919 - val_acc: 0.7895
# Epoch 26/200
# 7/7 [==============================] - 1s 109ms/step - loss: 0.5595 - acc: 0.7488 - val_loss: 0.5048 - val_acc: 0.7895
# Epoch 27/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5583 - acc: 0.7442 - val_loss: 0.4661 - val_acc: 0.8158
# Epoch 28/200
# 7/7 [==============================] - 1s 107ms/step - loss: 0.5699 - acc: 0.7070 - val_loss: 0.4489 - val_acc: 0.8158
# Epoch 29/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5340 - acc: 0.7488 - val_loss: 0.4378 - val_acc: 0.8158
# Epoch 30/200
# 7/7 [==============================] - 1s 113ms/step - loss: 0.5577 - acc: 0.7535 - val_loss: 0.4798 - val_acc: 0.8158
# Epoch 31/200
# 7/7 [==============================] - 1s 107ms/step - loss: 0.5481 - acc: 0.7488 - val_loss: 0.4730 - val_acc: 0.7895
# Epoch 32/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5670 - acc: 0.7256 - val_loss: 0.4135 - val_acc: 0.8158
# Epoch 33/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5515 - acc: 0.7442 - val_loss: 0.4480 - val_acc: 0.8158
# Epoch 34/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5814 - acc: 0.6930 - val_loss: 0.4378 - val_acc: 0.8158
# Epoch 35/200
# 7/7 [==============================] - 1s 109ms/step - loss: 0.5339 - acc: 0.7488 - val_loss: 0.4005 - val_acc: 0.8421
# Epoch 36/200
# 7/7 [==============================] - 1s 110ms/step - loss: 0.5344 - acc: 0.7442 - val_loss: 0.5052 - val_acc: 0.7895
# Epoch 37/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5550 - acc: 0.7209 - val_loss: 0.4539 - val_acc: 0.8158
# Epoch 38/200
# 7/7 [==============================] - 1s 107ms/step - loss: 0.5404 - acc: 0.7256 - val_loss: 0.4373 - val_acc: 0.8158
# Epoch 39/200
# 7/7 [==============================] - 1s 108ms/step - loss: 0.5620 - acc: 0.7209 - val_loss: 0.4229 - val_acc: 0.8158
# Epoch 40/200
# 7/7 [==============================] - 1s 123ms/step - loss: 0.5219 - acc: 0.7581 - val_loss: 0.4306 - val_acc: 0.7895
# Epoch 41/200
# 7/7 [==============================] - 1s 108ms/step - loss: 0.5521 - acc: 0.7302 - val_loss: 0.4330 - val_acc: 0.7895
# Epoch 42/200
# 7/7 [==============================] - 1s 107ms/step - loss: 0.5178 - acc: 0.7442 - val_loss: 0.4588 - val_acc: 0.7895
# Epoch 43/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5266 - acc: 0.7116 - val_loss: 0.4045 - val_acc: 0.8158
# Epoch 44/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.5281 - acc: 0.7488 - val_loss: 0.4475 - val_acc: 0.8158
# Epoch 45/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5394 - acc: 0.7256 - val_loss: 0.4463 - val_acc: 0.7895
# Epoch 46/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.5196 - acc: 0.7395 - val_loss: 0.4073 - val_acc: 0.8158
# Epoch 47/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5240 - acc: 0.7488 - val_loss: 0.4065 - val_acc: 0.8158
# Epoch 48/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.5242 - acc: 0.7488 - val_loss: 0.4213 - val_acc: 0.7895
# Epoch 49/200
# 7/7 [==============================] - 1s 106ms/step - loss: 0.5204 - acc: 0.7535 - val_loss: 0.4473 - val_acc: 0.7895
# Epoch 50/200
# 7/7 [==============================] - 1s 108ms/step - loss: 0.5215 - acc: 0.7488 - val_loss: 0.4289 - val_acc: 0.7895
# Epoch 51/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.5243 - acc: 0.7442 - val_loss: 0.4376 - val_acc: 0.7895
# Epoch 52/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.4798 - acc: 0.7907 - val_loss: 0.3848 - val_acc: 0.8421
# Epoch 53/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5372 - acc: 0.7581 - val_loss: 0.4053 - val_acc: 0.7895
# Epoch 54/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.5209 - acc: 0.7349 - val_loss: 0.3789 - val_acc: 0.8158
# Epoch 55/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5119 - acc: 0.7721 - val_loss: 0.3759 - val_acc: 0.8158
# Epoch 56/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.5179 - acc: 0.7721 - val_loss: 0.3818 - val_acc: 0.8158
# Epoch 57/200
# 7/7 [==============================] - 1s 113ms/step - loss: 0.5177 - acc: 0.7628 - val_loss: 0.3817 - val_acc: 0.8158
# Epoch 58/200
# 7/7 [==============================] - 1s 115ms/step - loss: 0.5073 - acc: 0.7721 - val_loss: 0.3774 - val_acc: 0.8158
# Epoch 59/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.4974 - acc: 0.7442 - val_loss: 0.3896 - val_acc: 0.7895
# Epoch 60/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.5004 - acc: 0.7767 - val_loss: 0.3788 - val_acc: 0.8158
# Epoch 61/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.4870 - acc: 0.7535 - val_loss: 0.3933 - val_acc: 0.7895
# Epoch 62/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.4897 - acc: 0.7581 - val_loss: 0.4036 - val_acc: 0.7895
# Epoch 63/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.5182 - acc: 0.7814 - val_loss: 0.3998 - val_acc: 0.7895
# Epoch 64/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.5011 - acc: 0.7116 - val_loss: 0.3652 - val_acc: 0.8158
# Epoch 65/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4782 - acc: 0.7767 - val_loss: 0.3690 - val_acc: 0.8158
# Epoch 66/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4904 - acc: 0.7674 - val_loss: 0.4035 - val_acc: 0.7895
# Epoch 67/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4942 - acc: 0.7628 - val_loss: 0.4013 - val_acc: 0.8158
# Epoch 68/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4836 - acc: 0.7860 - val_loss: 0.3711 - val_acc: 0.8158
# Epoch 69/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4570 - acc: 0.7814 - val_loss: 0.3890 - val_acc: 0.7895
# Epoch 70/200
# 7/7 [==============================] - 1s 94ms/step - loss: 0.5124 - acc: 0.7581 - val_loss: 0.3944 - val_acc: 0.7895
# Epoch 71/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4757 - acc: 0.7767 - val_loss: 0.3976 - val_acc: 0.8158
# Epoch 72/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.4823 - acc: 0.7907 - val_loss: 0.3972 - val_acc: 0.8158
# Epoch 73/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4873 - acc: 0.7721 - val_loss: 0.4194 - val_acc: 0.8421
# Epoch 74/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.4839 - acc: 0.7674 - val_loss: 0.4203 - val_acc: 0.8158
# Epoch 75/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4939 - acc: 0.7721 - val_loss: 0.3939 - val_acc: 0.8158
# Epoch 76/200
# 7/7 [==============================] - 1s 95ms/step - loss: 0.4814 - acc: 0.7674 - val_loss: 0.3932 - val_acc: 0.8158
# Epoch 77/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4875 - acc: 0.8047 - val_loss: 0.3874 - val_acc: 0.8158
# Epoch 78/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4704 - acc: 0.7860 - val_loss: 0.3900 - val_acc: 0.8421
# Epoch 79/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4774 - acc: 0.7767 - val_loss: 0.4003 - val_acc: 0.8158
# Epoch 80/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4308 - acc: 0.8186 - val_loss: 0.4253 - val_acc: 0.8158
# Epoch 81/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4790 - acc: 0.7814 - val_loss: 0.4214 - val_acc: 0.8421
# Epoch 82/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.5127 - acc: 0.7767 - val_loss: 0.3804 - val_acc: 0.8158
# Epoch 83/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4451 - acc: 0.8140 - val_loss: 0.3960 - val_acc: 0.8158
# Epoch 84/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.4392 - acc: 0.8000 - val_loss: 0.3661 - val_acc: 0.8158
# Epoch 85/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4815 - acc: 0.7907 - val_loss: 0.4080 - val_acc: 0.8158
# Epoch 86/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4571 - acc: 0.7907 - val_loss: 0.4290 - val_acc: 0.8158
# Epoch 87/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4679 - acc: 0.8000 - val_loss: 0.4437 - val_acc: 0.8158
# Epoch 88/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4392 - acc: 0.8000 - val_loss: 0.3885 - val_acc: 0.8158
# Epoch 89/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4421 - acc: 0.8093 - val_loss: 0.3860 - val_acc: 0.8158
# Epoch 90/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4202 - acc: 0.8140 - val_loss: 0.4197 - val_acc: 0.8158
# Epoch 91/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4001 - acc: 0.7953 - val_loss: 0.3838 - val_acc: 0.8158
# Epoch 92/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4373 - acc: 0.8279 - val_loss: 0.3641 - val_acc: 0.8421
# Epoch 93/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.4262 - acc: 0.7953 - val_loss: 0.3533 - val_acc: 0.8421
# Epoch 94/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.4089 - acc: 0.8093 - val_loss: 0.3412 - val_acc: 0.8421
# Epoch 95/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.4002 - acc: 0.8140 - val_loss: 0.3450 - val_acc: 0.8421
# Epoch 96/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3668 - acc: 0.8372 - val_loss: 0.3916 - val_acc: 0.8158
# Epoch 97/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.3888 - acc: 0.8372 - val_loss: 0.3150 - val_acc: 0.8421
# Epoch 98/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3934 - acc: 0.8233 - val_loss: 0.3726 - val_acc: 0.8158
# Epoch 99/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3795 - acc: 0.8419 - val_loss: 0.3831 - val_acc: 0.8158
# Epoch 100/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3743 - acc: 0.8186 - val_loss: 0.3089 - val_acc: 0.8421
# Epoch 101/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3784 - acc: 0.8419 - val_loss: 0.4042 - val_acc: 0.8158
# Epoch 102/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3589 - acc: 0.8326 - val_loss: 0.3382 - val_acc: 0.8684
# Epoch 103/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3472 - acc: 0.8279 - val_loss: 0.3755 - val_acc: 0.8158
# Epoch 104/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3828 - acc: 0.8233 - val_loss: 0.3449 - val_acc: 0.8684
# Epoch 105/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3599 - acc: 0.8279 - val_loss: 0.3412 - val_acc: 0.8421
# Epoch 106/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3570 - acc: 0.8419 - val_loss: 0.3126 - val_acc: 0.8684
# Epoch 107/200
# 7/7 [==============================] - 1s 91ms/step - loss: 0.3519 - acc: 0.8326 - val_loss: 0.2990 - val_acc: 0.8947
# Epoch 108/200
# 7/7 [==============================] - 1s 91ms/step - loss: 0.3235 - acc: 0.8605 - val_loss: 0.2896 - val_acc: 0.8684
# Epoch 109/200
# 7/7 [==============================] - 1s 91ms/step - loss: 0.3342 - acc: 0.8186 - val_loss: 0.3171 - val_acc: 0.8421
# Epoch 110/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3363 - acc: 0.8558 - val_loss: 0.3277 - val_acc: 0.8421
# Epoch 111/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3220 - acc: 0.8372 - val_loss: 0.3094 - val_acc: 0.8421
# Epoch 112/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3224 - acc: 0.8744 - val_loss: 0.2955 - val_acc: 0.8684
# Epoch 113/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2935 - acc: 0.8791 - val_loss: 0.4563 - val_acc: 0.7895
# Epoch 114/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.3177 - acc: 0.8558 - val_loss: 0.2843 - val_acc: 0.8421
# Epoch 115/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2970 - acc: 0.8744 - val_loss: 0.2680 - val_acc: 0.8684
# Epoch 116/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2741 - acc: 0.8744 - val_loss: 0.2739 - val_acc: 0.8421
# Epoch 117/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2884 - acc: 0.8605 - val_loss: 0.3533 - val_acc: 0.8421
# Epoch 118/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2717 - acc: 0.8977 - val_loss: 0.3917 - val_acc: 0.7895
# Epoch 119/200
# 7/7 [==============================] - 1s 95ms/step - loss: 0.2672 - acc: 0.8837 - val_loss: 0.2822 - val_acc: 0.9211
# Epoch 120/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2625 - acc: 0.8884 - val_loss: 0.3249 - val_acc: 0.8421
# Epoch 121/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2606 - acc: 0.8744 - val_loss: 0.2665 - val_acc: 0.8421
# Epoch 122/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2548 - acc: 0.8930 - val_loss: 0.3930 - val_acc: 0.7632
# Epoch 123/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2683 - acc: 0.8744 - val_loss: 0.2520 - val_acc: 0.8947
# Epoch 124/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2696 - acc: 0.8930 - val_loss: 0.2584 - val_acc: 0.8684
# Epoch 125/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2481 - acc: 0.9116 - val_loss: 0.3193 - val_acc: 0.8158
# Epoch 126/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2630 - acc: 0.8744 - val_loss: 0.3198 - val_acc: 0.8158
# Epoch 127/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2419 - acc: 0.9209 - val_loss: 0.2507 - val_acc: 0.8947
# Epoch 128/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2320 - acc: 0.9163 - val_loss: 0.2757 - val_acc: 0.8421
# Epoch 129/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2279 - acc: 0.9070 - val_loss: 0.2629 - val_acc: 0.8947
# Epoch 130/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2435 - acc: 0.9070 - val_loss: 0.2860 - val_acc: 0.8421
# Epoch 131/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2214 - acc: 0.9209 - val_loss: 0.3048 - val_acc: 0.8421
# Epoch 132/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2287 - acc: 0.9302 - val_loss: 0.2720 - val_acc: 0.8684
# Epoch 133/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.2064 - acc: 0.9163 - val_loss: 0.2301 - val_acc: 0.8684
# Epoch 134/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.2424 - acc: 0.9023 - val_loss: 0.2880 - val_acc: 0.8684
# Epoch 135/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1858 - acc: 0.9349 - val_loss: 0.2805 - val_acc: 0.8684
# Epoch 136/200
# 7/7 [==============================] - 1s 95ms/step - loss: 0.2170 - acc: 0.9163 - val_loss: 0.2497 - val_acc: 0.8947
# Epoch 137/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2054 - acc: 0.9209 - val_loss: 0.2410 - val_acc: 0.8947
# Epoch 138/200
# 7/7 [==============================] - 1s 96ms/step - loss: 0.1802 - acc: 0.9488 - val_loss: 0.3217 - val_acc: 0.8158
# Epoch 139/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.2122 - acc: 0.9256 - val_loss: 0.2613 - val_acc: 0.8421
# Epoch 140/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1954 - acc: 0.9256 - val_loss: 0.2403 - val_acc: 0.8947
# Epoch 141/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1748 - acc: 0.9442 - val_loss: 0.2540 - val_acc: 0.8421
# Epoch 142/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1627 - acc: 0.9442 - val_loss: 0.2520 - val_acc: 0.8684
# Epoch 143/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1631 - acc: 0.9395 - val_loss: 0.2453 - val_acc: 0.8947
# Epoch 144/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1925 - acc: 0.9256 - val_loss: 0.2399 - val_acc: 0.8947
# Epoch 145/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1820 - acc: 0.9349 - val_loss: 0.2555 - val_acc: 0.8947
# Epoch 146/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1730 - acc: 0.9442 - val_loss: 0.2946 - val_acc: 0.8421
# Epoch 147/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1631 - acc: 0.9442 - val_loss: 0.2619 - val_acc: 0.8684
# Epoch 148/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1473 - acc: 0.9581 - val_loss: 0.2599 - val_acc: 0.8684
# Epoch 149/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1789 - acc: 0.9302 - val_loss: 0.2623 - val_acc: 0.8684
# Epoch 150/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1357 - acc: 0.9674 - val_loss: 0.2514 - val_acc: 0.8684
# Epoch 151/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1575 - acc: 0.9535 - val_loss: 0.2785 - val_acc: 0.8421
# Epoch 152/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1778 - acc: 0.9395 - val_loss: 0.2362 - val_acc: 0.8684
# Epoch 153/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1555 - acc: 0.9535 - val_loss: 0.2569 - val_acc: 0.8421
# Epoch 154/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1795 - acc: 0.9442 - val_loss: 0.2901 - val_acc: 0.8421
# Epoch 155/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1536 - acc: 0.9488 - val_loss: 0.2481 - val_acc: 0.8684
# Epoch 156/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1376 - acc: 0.9767 - val_loss: 0.2704 - val_acc: 0.8421
# Epoch 157/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1586 - acc: 0.9535 - val_loss: 0.2240 - val_acc: 0.8684
# Epoch 158/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.1475 - acc: 0.9628 - val_loss: 0.2121 - val_acc: 0.8684
# Epoch 159/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1483 - acc: 0.9349 - val_loss: 0.2469 - val_acc: 0.8684
# Epoch 160/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1480 - acc: 0.9488 - val_loss: 0.2343 - val_acc: 0.8684
# Epoch 161/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1456 - acc: 0.9488 - val_loss: 0.2614 - val_acc: 0.8684
# Epoch 162/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1476 - acc: 0.9535 - val_loss: 0.2221 - val_acc: 0.8684
# Epoch 163/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1320 - acc: 0.9581 - val_loss: 0.2166 - val_acc: 0.8684
# Epoch 164/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1264 - acc: 0.9628 - val_loss: 0.2437 - val_acc: 0.8684
# Epoch 165/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1189 - acc: 0.9767 - val_loss: 0.2168 - val_acc: 0.8684
# Epoch 166/200
# 7/7 [==============================] - 1s 113ms/step - loss: 0.1226 - acc: 0.9674 - val_loss: 0.2666 - val_acc: 0.8421
# Epoch 167/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1192 - acc: 0.9674 - val_loss: 0.2377 - val_acc: 0.8684
# Epoch 168/200
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1134 - acc: 0.9814 - val_loss: 0.2289 - val_acc: 0.8684
# Epoch 169/200
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1315 - acc: 0.9535 - val_loss: 0.2768 - val_acc: 0.8421
# Epoch 170/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1205 - acc: 0.9581 - val_loss: 0.2485 - val_acc: 0.8684
# Epoch 171/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1218 - acc: 0.9535 - val_loss: 0.2274 - val_acc: 0.8684
# Epoch 172/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1136 - acc: 0.9767 - val_loss: 0.2268 - val_acc: 0.8684
# Epoch 173/200
# 7/7 [==============================] - 1s 107ms/step - loss: 0.1254 - acc: 0.9721 - val_loss: 0.2207 - val_acc: 0.8684
# Epoch 174/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0993 - acc: 0.9767 - val_loss: 0.2278 - val_acc: 0.8421
# Epoch 175/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0908 - acc: 0.9767 - val_loss: 0.2090 - val_acc: 0.9211
# Epoch 176/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0936 - acc: 0.9860 - val_loss: 0.2315 - val_acc: 0.8421
# Epoch 177/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.1165 - acc: 0.9581 - val_loss: 0.2520 - val_acc: 0.8421
# Epoch 178/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.1080 - acc: 0.9767 - val_loss: 0.2517 - val_acc: 0.8421
# Epoch 179/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.1056 - acc: 0.9674 - val_loss: 0.2712 - val_acc: 0.8421
# Epoch 180/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0908 - acc: 0.9907 - val_loss: 0.2353 - val_acc: 0.8421
# Epoch 181/200
# 7/7 [==============================] - 1s 106ms/step - loss: 0.1110 - acc: 0.9767 - val_loss: 0.2372 - val_acc: 0.8684
# Epoch 182/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1013 - acc: 0.9674 - val_loss: 0.2389 - val_acc: 0.8684
# Epoch 183/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0984 - acc: 0.9767 - val_loss: 0.2484 - val_acc: 0.8684
# Epoch 184/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.1007 - acc: 0.9767 - val_loss: 0.2796 - val_acc: 0.8421
# Epoch 185/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.1111 - acc: 0.9721 - val_loss: 0.2569 - val_acc: 0.8684
# Epoch 186/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0829 - acc: 0.9860 - val_loss: 0.2481 - val_acc: 0.8684
# Epoch 187/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0703 - acc: 0.9907 - val_loss: 0.2536 - val_acc: 0.8684
# Epoch 188/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0774 - acc: 0.9860 - val_loss: 0.2487 - val_acc: 0.8684
# Epoch 189/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0833 - acc: 0.9953 - val_loss: 0.2355 - val_acc: 0.8684
# Epoch 190/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0732 - acc: 0.9907 - val_loss: 0.2358 - val_acc: 0.9211
# Epoch 191/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0809 - acc: 0.9860 - val_loss: 0.2365 - val_acc: 0.9211
# Epoch 192/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0829 - acc: 0.9628 - val_loss: 0.2534 - val_acc: 0.8684
# Epoch 193/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0650 - acc: 0.9953 - val_loss: 0.2455 - val_acc: 0.8684
# Epoch 194/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0664 - acc: 1.0000 - val_loss: 0.2470 - val_acc: 0.8684
# Epoch 195/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.0726 - acc: 0.9907 - val_loss: 0.2620 - val_acc: 0.8684
# Epoch 196/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0726 - acc: 0.9907 - val_loss: 0.2534 - val_acc: 0.8684
# Epoch 197/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.0858 - acc: 0.9814 - val_loss: 0.2396 - val_acc: 0.8684
# Epoch 198/200
# 7/7 [==============================] - 1s 101ms/step - loss: 0.0661 - acc: 0.9814 - val_loss: 0.2400 - val_acc: 0.9211
# Epoch 199/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.0591 - acc: 0.9953 - val_loss: 0.2536 - val_acc: 0.8684
# Epoch 200/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.0757 - acc: 0.9860 - val_loss: 0.2482 - val_acc: 0.8684

# %%
visualkeras.layered_view(model, to_file='../Model Graphs and Imgs/model.png') # write to disk
# Out:
# <PIL.Image.Image image mode=RGBA size=930x672 at 0x7F8CF0085400>

# %%
# Let's calculate our accuracy score
score = model.evaluate(testImages, testLabels, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.8684210777282715

# %%
# Let's predict on out testing set
prediction = model.predict(testImages)

# %%
labels =['no', 'yes']

# %%
# Let's create the directories to save the images labeled as 1 or true
# to draw the countour later

# Images will be saved at /predicted/raw/
if os.path.isdir('../predicted/raw/'):
    shutil.rmtree('../predicted/raw/')

os.mkdir('../predicted/raw/')

# %%
# Plotting final results to evaluate model
y_hat = model.predict(testImages)


figure = plt.figure(figsize=(20, 14))
for i, index in enumerate(np.random.choice(testImages.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(testImages[index]))
    predict_index = int(round(y_hat[index][0]))
    true_index = np.argmax(testLabels[index])

    if predict_index == 1:
        plt.title('Tumor Found', color='r')
        plt.imsave('../predicted/raw/predImg{}.jpg'.format(index), testImages[index])
    else:
        plt.title('No Tumor Found', color='g')
    plt.xlabel('Actual:{} - Predicted:{}'.format(testLabels[index], y_hat[index]))
plt.show()

# %%
# Plot model accuracy
plt.plot(history.history['acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# Plot model loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Run the second notebook
# %run ./contouring.ipynb
# Out:
# Created file @ "../predicted/drawn/final0.jpg"
# Created file @ "../predicted/drawn/final1.jpg"
# Created file @ "../predicted/drawn/final2.jpg"
# Created file @ "../predicted/drawn/final3.jpg"
# Created file @ "../predicted/drawn/final4.jpg"
# Created file @ "../predicted/drawn/final5.jpg"
# Created file @ "../predicted/drawn/final6.jpg"
# Created file @ "../predicted/drawn/final7.jpg"
# Created file @ "../predicted/drawn/final8.jpg"
# Created file @ "../predicted/drawn/final9.jpg"
